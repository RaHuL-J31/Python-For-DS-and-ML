# %% [markdown]
# # Plotly-and-Cufflinks
# ### Plotly is an interactive vizualization library Cufflinks connects plotly with pandas

# %%
import numpy as np
import pandas as pd
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot 
import cufflinks as cf
init_notebook_mode(connected=True)
import plotly.graph_objs as go
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
# %matplotlib inline
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df1 = pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())
df1
# Out:
#            A         B         C         D
# 0   0.859295  0.916981  0.205690  0.086634
# 1   0.012634  1.202431  0.038758  0.286130
# 2  -0.689639 -1.371033  0.455221  0.525547
# 3   0.532714 -0.829690 -0.896280  0.619139
# 4  -0.215778  0.519115 -1.923938  1.494557
# ..       ...       ...       ...       ...
# 95  1.171141  0.050015 -0.192417 -0.386093
# 96 -0.113064 -1.141015 -1.285883  0.167817
# 97 -0.209724 -1.487807 -0.783927  0.895326
# 98 -1.527903 -0.044543  0.534279 -0.759947
# 99 -0.790102  0.960277  1.629368 -0.596423
#
# [100 rows x 4 columns]

# %%
df2 = pd.DataFrame({'Catagory':['A','B','C'],'Values':[32,42,50]})
df2
# Out:
#   Catagory  Values
# 0        A      32
# 1        B      42
# 2        C      50

# %%
df1.iplot()
# Out:
# <div>                            <div id="8ca01fa8-2d00-4053-92c5-3a04da185488" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.iplot(kind='scatter',x='A',y='B',mode='markers')
# Out:
# <div>                            <div id="637cc594-25ed-4e5d-a56e-98d79af7c782" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df2.plot(kind='bar',x='Catagory',y='Values')
# Out:
# <AxesSubplot:xlabel='Catagory'>

# %%
df1.sum().iplot(kind='bar')
# Out:
# <div>                            <div id="e7398857-9bd7-481d-9191-f746aa1c3d33" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.iplot(kind='box')
# Out:
# <div>                            <div id="a5b3a06f-2113-42a3-93b7-dee04e0a333a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,40,50],'z':[100,200,300,400,500]})
df3
# Out:
#    x   y    z
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300
# 3  4  40  400
# 4  5  50  500

# %%
df3.iplot(kind='surface')
# Out:
# <div>                            <div id="c094d0f5-ad1a-402f-8e04-6ffefabf91fa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.iplot(kind='hist')
# Out:
# <div>                            <div id="ededa5b4-11ad-4322-8a77-c2b41c253022" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1[['A','B']].iplot(kind='spread')
# Out:
# c:\users\rahul31\appdata\local\programs\python\python39\lib\site-packages\cufflinks\plotlytools.py:849: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#
# c:\users\rahul31\appdata\local\programs\python\python39\lib\site-packages\cufflinks\plotlytools.py:850: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
# <div>                            <div id="84883cef-d08a-41ff-8a98-206c860a9df2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.iplot(kind='bubble',x='A',y='B',size='C')
# Out:
# <div>                            <div id="3bb4c8ec-dd4c-4404-99bb-fa88582873fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.scatter_matrix()
# Out:
# <div>                            <div id="f1e459c0-7259-4335-85ad-01fd147037d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
